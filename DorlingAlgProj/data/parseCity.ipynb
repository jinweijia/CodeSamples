# %%
import pandas as pd
import csv

# %%
CITY_DATA_PATH = 'zip_code_database.csv'
CITY = 'Las Vegas'
AREACODE = { 'Las Vegas': '702' }


df = pd.DataFrame.from_csv(CITY_DATA_PATH)
cityData = df[(df['primary_city'] == CITY) & (df['type'] == 'STANDARD') & (df['area_codes'] == AREACODE[CITY])].ix[:,['latitude','longitude','estimated_population']]
df_filtered
# Out:
#        latitude  longitude  estimated_population
# zip
# 89101     36.17    -115.12                 29222
# 89102     36.14    -115.18                 28031
# 89103     36.11    -115.21                 36409
# 89104     36.15    -115.11                 31514
# 89106     36.18    -115.17                 18467
# 89107     36.17    -115.20                 28148
# 89108     36.21    -115.21                 51274
# 89109     36.11    -115.12                  5441
# 89110     36.17    -115.05                 54825
# 89113     36.06    -115.27                 18126
# 89115     36.23    -115.05                 40398
# 89117     36.14    -115.27                 43411
# 89118     36.07    -115.21                 14459
# 89119     36.08    -115.14                 33393
# 89120     36.07    -115.08                 18410
# 89121     36.12    -115.08                 47506
# 89122     36.10    -115.02                 33634
# 89123     36.00    -115.14                 42113
# ...

# %%
s = city_vegas['area_codes']
s = city_vegas['area_codes'] == '702'
s.item()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-761a41acf15e> in <module>()
#       1 s = city_vegas['area_codes']
#       2 s = city_vegas['area_codes'] == '702'
# ----> 3 s.item()
#
# /home/jin/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in item(self)
#     291     # ndarray compatibility
#     292     def item(self):
# --> 293         return self._data.values.item()
#     294
#     295     @property
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
city_vegas = df[df['primary_city'] == 'Las Vegas']
r = city_vegas[(city_vegas['type'] == 'STANDARD') & (city_vegas['area_codes'] == '702')]
r.shape
# city_vegas[city_vegas['area_codes'] == '702']
# city_vegas[city_vegas.index.isin(zipcodes)]
# Out:
# (45, 15)

# %%
zipcodes = [int(x) for x in zipcodes]
lv = df[df.index.isin(zipcodes)]
lv.shape
# Out:
# (69, 11)

# %%
set(lv['City'])
# Out:
# {'HENDERSON', 'JEAN', 'LAS VEGAS', 'NELLIS AFB', 'NORTH LAS VEGAS'}

# %%
lv.head()
# Out:
#         ZipCodeType       City State LocationType    Lat    Long  \
# Zipcode
# 89014      STANDARD  HENDERSON    NV      PRIMARY  36.05 -115.05
# 89044      STANDARD  HENDERSON    NV      PRIMARY  35.88 -115.04
# 89052      STANDARD  HENDERSON    NV      PRIMARY  35.98 -115.11
# 89074      STANDARD  HENDERSON    NV      PRIMARY  36.03 -115.07
# 89019      STANDARD       JEAN    NV      PRIMARY  35.75 -115.53
#
#                    Location Decommisioned  TaxReturnsFiled  \
# Zipcode
# 89014    NA-US-NV-HENDERSON         False            18409
# 89044    NA-US-NV-HENDERSON         False             7020
# 89052    NA-US-NV-HENDERSON         False            22270
# 89074    NA-US-NV-HENDERSON         False            22914
# 89019         NA-US-NV-JEAN         False             1348
#
#          EstimatedPopulation  TotalWages
# Zipcode
# 89014                  30076   765546371
# 89044                  12009   370148528
# 89052                  38648  1347178117
# ...

# %%
cityData = lv.ix[:,[4,5,9,10]]
# Out:
#            Lat    Long  EstimatedPopulation  TotalWages
# Zipcode
# 89014    36.05 -115.05                30076   765546371
# 89044    35.88 -115.04                12009   370148528
# 89052    35.98 -115.11                38648  1347178117
# 89074    36.03 -115.07                38386  1145529343
# 89019    35.75 -115.53                 2184    44592830
# 89101    36.17 -115.12                29222   381708617
# 89102    36.14 -115.18                28031   459616937
# 89103    36.11 -115.21                36409   682807027
# 89104    36.15 -115.11                31514   490695632
# 89106    36.18 -115.17                18467   266249325
# 89107    36.17 -115.20                28148   510119371
# 89108    36.21 -115.21                51274   947198998
# 89109    36.11 -115.12                 5441   240045522
# 89110    36.17 -115.05                54825   946191205
# 89111    36.08 -115.14                  NaN         NaN
# 89112    36.11 -115.01                 1151    22632447
# ...
