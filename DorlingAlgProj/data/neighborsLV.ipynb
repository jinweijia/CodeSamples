# %%
import json
import csv

# %%
DATA_PATH = 'LasVegasData_final.json'

with open( DATA_PATH ) as f:      
    value = f.read().replace('\n', '')
    data = json.loads(value)
    
type(data)
# Out:
# dict

# %%
k = sorted(data.keys())
k
with open('LasVegasZipcodes.csv', 'wb') as csvfile:
    spamwriter = csv.writer(csvfile, quoting=csv.QUOTE_ALL)
    spamwriter.writerow(k)

# %%
k
# Out:
# [u'89101',
#  u'89102',
#  u'89103',
#  u'89104',
#  u'89106',
#  u'89107',
#  u'89108',
#  u'89109',
#  u'89110',
#  u'89113',
#  u'89115',
#  u'89117',
#  u'89118',
#  u'89119',
#  u'89120',
#  u'89121',
#  u'89122',
#  u'89123',
#  u'89124',
#  u'89128',
#  u'89129',
#  u'89130',
#  u'89131',
#  u'89134',
#  u'89135',
#  u'89138',
#  u'89139',
#  u'89141',
#  u'89142',
#  u'89143',
#  u'89144',
#  u'89145',
#  u'89146',
#  u'89147',
#  u'89148',
#  u'89149',
#  u'89158',
#  u'89166',
#  u'89169',
#  u'89178',
#  u'89179',
#  u'89183',
#  u'89199']

# %%
filter(lambda x: str(x) not in neighbors.keys(), k)
# Out:
# []

# %%
neighbors = {
'89002': ['89005','89015','89012'],
'89005': ['89002'],
'89011': [],
'89012': [],
'89014': [],
'89015': [],
'89030': [],
'89031': [],
'89032': [],
'89044': [],
'89052': [],
'89074': [],
'89081': [],
'89084': [],
'89085': [],
'89086': [],
'89087': [],
'89101': ['89030','89115','89110','89104','89102','89106'],
'89102': ['89106','89101','89104','89109','89103','89146','89107'],
'89103': ['89102','89109','89118','89113','89147','89146'],
'89104': ['89101','89110','89142','89121','89169','89109','89102'],
'89106': ['89032','89030','89101','89102','89107','89108'],
'89107': ['89108','89106','89102','89146','89145'],
'89108': ['89130','89032','89106','89107','89145','89149'],
'89109': ['89102','89104','89169','89119','89118','89103'],
'89110': ['89115','89156','89142','89104','89101'],
'89113': ['89147','89118','89139','89178','89148'],
'89115': ['89165','89191','89156','89110','89030','89081'],
'89117': ['89145','89146','89147','89135'],
'89118': ['89103','89119','89109','89123','89139','89113'],
'89119': ['89169','89121','89120','89123','89118','89109'],
'89120': ['89121','89122','89014','89074','89123','89119'],
'89121': ['89104','89142','89122','89120','89119','89169'],
'89122': ['89142','89011','89014','89120','89121'],
'89123': ['89119','89120','89074','89183','89141','89139','89118'],
'89124': ['89018','89129','89128','89048','89061','89004','89135','89138','89134','89149','89143','89131','89085','89086'],
'89128': ['89018','89129','89124','89060','89048'],
'89129': ['89018','89124','89128'],
'89130': ['89131','89031','89032','89108','89149'],
'89131': ['89124','89085','89084','89031','89130','89149','89143'],
'89134': ['89124','89149','89145','89144','89138'],
'89135': ['89124','89138','89144','89145','89117','89147','89178','89161','89004'],
'89138': ['89124','89134','89144','89135'],
'89139': ['89118','89123','89141','89179','89178','89113'],
'89141': ['89139','89123','89183','89044','89054','89179'],
'89142': ['89110','89122','89121','89104'],
'89143': ['89124','89131','89149'],
'89144': ['89134','89145','89135','89138'],
'89145': ['89149','89108','89107','89117','89135','89144','89134'],
'89146': ['89107','89102','89103','89147','89117'],
'89147': ['89117','89146','89103','89113','89148','89135'],
'89148': ['89147','89113','89178','891345'],
'89149': ['89143','89131','89130','89108','89145','89134','89124'],
'89156': ['89191','89110','89115'],
'89158': ['89108','89106'],
'89161': ['89178','89004','89135'],
'89165': ['89115'],
'89166': ['89124','89131','89148'],
'89169': ['89104','89121','89119','89109'],
'89178': ['89135','89148','89113','89139','89179','89004','89161'],
'89179': ['89178','89139','89141','89054'],
'89183': ['89123','89074','89052','89044','89141'],
'89191': [],
'89199': ['89119']
}

# %%
with open('LasVegasNeighbors.json', 'w') as fp:
    json.dump(neighbors, fp)
